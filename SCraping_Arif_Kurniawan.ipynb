# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews



result, continuation_token = reviews(
    'com.shopee.id',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=10000,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId         userName  \
# 0  6f205ef4-b2a9-4a16-8a85-0eb8c4b5fc08  Pengguna Google
# 1  12c68391-32b5-4306-a749-4b9e88223898  Pengguna Google
# 2  b87799c3-09b6-4287-a85d-c601e9fdc670  Pengguna Google
# 3  b3ec9ff3-7b6a-4f68-96ab-c02e21781e5f  Pengguna Google
# 4  1a2569a6-418e-451b-aca8-7cea3af4c7a2  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                             lebih mudah dan amanah      5              0
# 1  chat kepenjual banyak yang tidak bisa ditampil...      2              0
# 2                                           opsional      2              0
# 3                                             banyak      5              0
# 4                                              Bagus      5              1
#
#   reviewCreatedVersion                  at  \
# 0              3.48.28 2025-04-21 18:17:04
# 1              3.47.39 2025-04-21 18:14:58
# 2                 None 2025-04-21 18:12:04
# 3                 None 2025-04-21 18:11:17
# 4                 None 2025-04-21 18:06:54
#
#                                         replyContent           repliedAt  \
# 0  Hi kak Ahmad , makasih ya buat bintang 5 nya, ... 2025-04-21 19:11:16
# 1  Hi kak Hakim , maaf atas kendala aplikasinya. ... 2025-04-21 19:10:30
# 2                                               None                 NaT
# 3  Hai kak Deni , waaah maaciw banyak yaw kak bua... 2025-04-21 19:10:33
# 4  Hai kak Rijik, waaah maaciw banyak yaw kak bua... 2025-04-21 19:10:00
#
#   appVersion
# 0    3.48.28
# 1    3.47.39
# 2       None
# 3       None
# 4       None

# %%
len(df_busu.index)
# Out:
# 10000

# %%
df_busu[['userName', 'score','at', 'content']].head()
# Out:
#           userName  score                  at  \
# 0  Pengguna Google      5 2025-04-21 18:17:04
# 1  Pengguna Google      2 2025-04-21 18:14:58
# 2  Pengguna Google      2 2025-04-21 18:12:04
# 3  Pengguna Google      5 2025-04-21 18:11:17
# 4  Pengguna Google      5 2025-04-21 18:06:54
#
#                                              content
# 0                             lebih mudah dan amanah
# 1  chat kepenjual banyak yang tidak bisa ditampil...
# 2                                           opsional
# 3                                             banyak
# 4                                              Bagus

# %%
my_df = df_busu[['userName', 'score','at', 'content']]

# %%
my_df.to_csv("scrapped_data_shope.csv", index = False)
